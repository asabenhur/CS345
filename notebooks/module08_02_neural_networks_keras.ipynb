# %% [markdown]
# *This notebook is part of  course materials for CS 345: Machine Learning Foundations and Practice at Colorado State University.
# Original versions were created by Ben Sattelberg and Asa Ben-Hur.
# The content is availabe [on GitHub](https://github.com/asabenhur/CS345).*
#
# *The text is released under the [CC BY-SA license](https://creativecommons.org/licenses/by-sa/4.0/), and code is released under the [MIT license](https://opensource.org/licenses/MIT).*
#
# <img style="padding: 10px; float:right;" alt="CC-BY-SA icon.svg in public domain" src="https://upload.wikimedia.org/wikipedia/commons/d/d0/CC-BY-SA_icon.svg" width="125">

# %% [markdown]
# <a href="https://colab.research.google.com/github//asabenhur/CS345/blob/master/notebooks/module08_02_neural_networks_keras.ipynb">
#   <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Neural Networks

# %%
# %autosave 0
# %matplotlib inline
import numpy as np
import keras
import matplotlib.pyplot as plt
import matplotlib
# Out:
# Autosave disabled

# %% [markdown]
# ### Plotting functionality for later

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_XOR_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')

    delta = 0.01
    xmin=-0.1;xmax=1.1;ymin=-0.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-1, vmax=1)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    X = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
    y = np.array([1, 0, 0, 1])

    plt.style.use('default')
    ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()

#     ax2.plot_wireframe(x_grid, y_grid, Z, alpha=0.5);
#     ax2.scatter(X[:,0], X[:,1], y, c=y, alpha=1, s=20, cmap='bwr')

#     ax2.set_xlabel('$x_1$')
#     ax2.set_ylabel('$x_2$')
#     ax2.set_zlabel('f($x_1$, $x_2$)');

# %%
def plot_circles_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')
    
    r1 = 0.5
    r2 = np.sqrt(2*r1**2)
    r3 = np.sqrt(r1**2 + r2**2)

    delta = 0.01
    xmin=-1.1;xmax=1.1;ymin=-1.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-0.001, vmax=0.001)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    plt.style.use('default')
    #ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()
    
    circle = plt.Circle((0, 0), r1, alpha=0.5, edgecolor='k')
    annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, facecolor='r', alpha=0.5, edgecolor='k')
    ax.add_artist(circle)
    ax.add_artist(annulus)

#     ax2.plot_wireframe(x_grid, y_grid, Z, alpha=0.5);

#     ax2.set_xlabel('$x_1$')
#     ax2.set_ylabel('$x_2$')
#     ax2.set_zlabel('f($x_1$, $x_2$)');

# %% [markdown]
# ## Introduction to Keras

# %% [markdown]
# Last time we introduced neural networks and built a simple architecture we could use to (sometimes) solve the XOR problem.  We saw the challenge of programming a network with increasing numbers of units and layers.
#
# Fortunately, there exist a number of packages designed for neural networks use that automatically determine the correct update rules with backpropagation.  A few of the packages that are used in CSU's CS department are TensorFlow, PyTorch, and Keras.  These packages use Python despite the fact that Python is can be relatively slow compared to compiled languages.  These deep learning packages often compile their code into those faster languages or are able to take advantage of optimizations that give competitive performance.
#
# We'll use Keras with a TensorFlow backend as it is simple to use and competitive with other options.

# %% [markdown]
# The [Keras website](https://keras.io/) has good tutorials and documentation.

# %% [markdown]
# First, we will create our dataset - the same XOR problem discussed in the previous notebook.  The only difference is that we convert the input values to be 32 bit floating point values, rather than 64 bit.  This isn't strictly necessary, but most neural network packages use 32 bit floats because the added precision is not worth the memory and computational cost.

# %%
X_xor = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y_xor = np.array([1, 0, 0, 1])

X_xor = X_xor.astype('float32')

# %% [markdown]
# Now we can set up a network.  We will use a ```Sequential``` network, which is the container for the multilayer perceptron/feedforward neural network structure we have been using so far.

# %%
network1 = keras.Sequential()

# %% [markdown]
# Now we can add layers to it.  The first layer we add is our hidden layer.  Having two nodes would give us a network which *can* work, but frequently doesn't, so let's create a much larger network with ten nodes in its hidden layer.  This is referred to as a ```Dense``` layer, as every input has a weight connecting it to every node in the previous layer.  We also tell Keras to use the ReLU activation function for it.
#
# Finally, we will add a layer that transforms the outputs of the hidden layer into the single output value.  By not passing an activation function in, this defaults to having no activation function.

# %%
network1.add(keras.layers.Dense(10, activation='relu'))
network1.add(keras.layers.Dense(1))

# %% [markdown]
# This sets up a network that looks like this:

# %% [markdown]
# <img style="padding:10px;width:80%;" alt="Simple multilayer perceptron architecture" src="https://github.com/asabenhur/CS345/raw/master/notebooks/figures/single_hidden_10_node.png">

# %% [markdown]
# Given the network, we can now set up the training process.  We will use the mean squared error as the loss function and use stochastic gradient descent as the optimzer:

# %%
loss_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.SGD(learning_rate=0.005)

# %% [markdown]
# The command ```network.compile(...)``` constructs the network as something that can be trained or evaluated.  The ```metrics``` parameter accepts a list of values that we want to keep track of during the training process.

# %%
network1.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %% [markdown]
# With all of the set up out of the way, we are ready to train the network.  The ```batch_size``` controls how many inputs to pass through the network at a time.   With traditional gradient descent it would be every input and with traditional stochastic gradient descent it would be a single input.  The ```verbose``` parameter controls to what extent the network prints output reflecting its progress.  Notice that it keeps track of the loss used for training, and the 'accuracy' and 'mse' values that we passed as metrics of interest.  In this case the loss is MSE, so the two values are the same.

# %%
history1 = network1.fit(X_xor, y_xor, batch_size=2, epochs=500, verbose=1)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6105 - accuracy: 0.5000 - mse: 0.6105
# Epoch 2/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5848 - accuracy: 0.5000 - mse: 0.5848
# Epoch 3/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5573 - accuracy: 0.5000 - mse: 0.5573
# Epoch 4/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5366 - accuracy: 0.5000 - mse: 0.5366
# Epoch 5/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5152 - accuracy: 0.5000 - mse: 0.5152
# Epoch 6/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4918 - accuracy: 0.5000 - mse: 0.4918
# Epoch 7/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4780 - accuracy: 0.5000 - mse: 0.4780
# Epoch 8/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.5000 - mse: 0.4586
# Epoch 9/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4465 - accuracy: 0.5000 - mse: 0.4465
# Epoch 10/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.5000 - mse: 0.4284
# Epoch 11/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4200 - accuracy: 0.5000 - mse: 0.4200
# Epoch 12/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.5000 - mse: 0.4040
# Epoch 13/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.5000 - mse: 0.3977
# Epoch 14/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.5000 - mse: 0.3880
# Epoch 15/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.5000 - mse: 0.3744
# Epoch 16/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.5000 - mse: 0.3704
# Epoch 17/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.5000 - mse: 0.3580
# Epoch 18/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3518 - accuracy: 0.5000 - mse: 0.3518
# Epoch 19/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.5000 - mse: 0.3453
# Epoch 20/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.5000 - mse: 0.3384
# Epoch 21/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.5000 - mse: 0.3375
# Epoch 22/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.5000 - mse: 0.3276
# Epoch 23/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.5000 - mse: 0.3229
# Epoch 24/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.5000 - mse: 0.3186
# Epoch 25/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3194 - accuracy: 0.5000 - mse: 0.3194
# Epoch 26/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3157 - accuracy: 0.5000 - mse: 0.3157
# Epoch 27/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3125 - accuracy: 0.5000 - mse: 0.3125
# Epoch 28/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3054 - accuracy: 0.5000 - mse: 0.3054
# Epoch 29/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3025 - accuracy: 0.5000 - mse: 0.3025
# Epoch 30/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.5000 - mse: 0.3038
# Epoch 31/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2972 - accuracy: 0.5000 - mse: 0.2972
# Epoch 32/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2941 - accuracy: 0.5000 - mse: 0.2941
# Epoch 33/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2928 - accuracy: 0.5000 - mse: 0.2928
# Epoch 34/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2901 - accuracy: 0.5000 - mse: 0.2901
# Epoch 35/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2883 - accuracy: 0.5000 - mse: 0.2883
# Epoch 36/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.2500 - mse: 0.2874
# Epoch 37/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2851 - accuracy: 0.5000 - mse: 0.2851
# Epoch 38/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.2500 - mse: 0.2844
# Epoch 39/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.2500 - mse: 0.2823
# Epoch 40/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2810 - accuracy: 0.2500 - mse: 0.2810
# Epoch 41/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2848 - accuracy: 0.2500 - mse: 0.2848
# Epoch 42/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.2500 - mse: 0.2795
# Epoch 43/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2826 - accuracy: 0.2500 - mse: 0.2826
# Epoch 44/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.2500 - mse: 0.2775
# Epoch 45/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.2500 - mse: 0.2807
# Epoch 46/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2799 - accuracy: 0.2500 - mse: 0.2799
# Epoch 47/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.2500 - mse: 0.2791
# Epoch 48/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2734 - accuracy: 0.2500 - mse: 0.2734
# Epoch 49/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2726 - accuracy: 0.2500 - mse: 0.2726
# Epoch 50/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.2500 - mse: 0.2727
# Epoch 51/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.2500 - mse: 0.2763
# Epoch 52/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2757 - accuracy: 0.2500 - mse: 0.2757
# Epoch 53/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.2500 - mse: 0.2751
# Epoch 54/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2696 - accuracy: 0.2500 - mse: 0.2696
# Epoch 55/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.2500 - mse: 0.2698
# Epoch 56/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.2500 - mse: 0.2685
# Epoch 57/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.2500 - mse: 0.2730
# Epoch 58/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2676 - accuracy: 0.2500 - mse: 0.2676
# Epoch 59/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.2500 - mse: 0.2720
# Epoch 60/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2715 - accuracy: 0.2500 - mse: 0.2715
# Epoch 61/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2668 - accuracy: 0.5000 - mse: 0.2668
# Epoch 62/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2657 - accuracy: 0.5000 - mse: 0.2657
# Epoch 63/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.5000 - mse: 0.2660
# Epoch 64/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2649 - accuracy: 0.5000 - mse: 0.2649
# Epoch 65/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2652 - accuracy: 0.5000 - mse: 0.2652
# Epoch 66/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2691 - accuracy: 0.5000 - mse: 0.2691
# Epoch 67/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2644 - accuracy: 0.5000 - mse: 0.2644
# Epoch 68/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2683 - accuracy: 0.5000 - mse: 0.2683
# Epoch 69/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.5000 - mse: 0.2637
# Epoch 70/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2627 - accuracy: 0.5000 - mse: 0.2627
# Epoch 71/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2623 - accuracy: 0.5000 - mse: 0.2623
# Epoch 72/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2626 - accuracy: 0.5000 - mse: 0.2626
# Epoch 73/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.5000 - mse: 0.2616
# Epoch 74/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2613 - accuracy: 0.5000 - mse: 0.2613
# Epoch 75/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2616 - accuracy: 0.5000 - mse: 0.2616
# Epoch 76/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.5000 - mse: 0.2606
# Epoch 77/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.5000 - mse: 0.2610
# Epoch 78/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.5000 - mse: 0.2600
# Epoch 79/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2597 - accuracy: 0.5000 - mse: 0.2597
# Epoch 80/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2643 - accuracy: 0.5000 - mse: 0.2643
# Epoch 81/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2597 - accuracy: 0.5000 - mse: 0.2597
# Epoch 82/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2636 - accuracy: 0.5000 - mse: 0.2636
# Epoch 83/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.5000 - mse: 0.2584
# Epoch 84/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2581 - accuracy: 0.5000 - mse: 0.2581
# Epoch 85/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.5000 - mse: 0.2584
# Epoch 86/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.5000 - mse: 0.2575
# Epoch 87/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2572 - accuracy: 0.5000 - mse: 0.2572
# Epoch 88/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.5000 - mse: 0.2618
# Epoch 89/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2566 - accuracy: 0.5000 - mse: 0.2566
# Epoch 90/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.5000 - mse: 0.2612
# Epoch 91/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2609 - accuracy: 0.5000 - mse: 0.2609
# Epoch 92/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2563 - accuracy: 0.5000 - mse: 0.2563
# Epoch 93/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.5000 - mse: 0.2554
# Epoch 94/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.5000 - mse: 0.2558
# Epoch 95/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.5000 - mse: 0.2548
# Epoch 96/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.5000 - mse: 0.2595
# Epoch 97/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2549 - accuracy: 0.5000 - mse: 0.2549
# Epoch 98/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2540 - accuracy: 0.5000 - mse: 0.2540
# Epoch 99/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2587 - accuracy: 0.5000 - mse: 0.2587
# Epoch 100/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2542 - accuracy: 0.5000 - mse: 0.2542
# Epoch 101/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 0.5000 - mse: 0.2533
# Epoch 102/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.5000 - mse: 0.2530
# Epoch 103/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2576 - accuracy: 0.5000 - mse: 0.2576
# Epoch 104/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2525 - accuracy: 0.5000 - mse: 0.2525
# Epoch 105/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.5000 - mse: 0.2529
# Epoch 106/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.5000 - mse: 0.2526
# Epoch 107/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2524 - accuracy: 0.5000 - mse: 0.2524
# Epoch 108/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.5000 - mse: 0.2515
# Epoch 109/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.5000 - mse: 0.2513
# Epoch 110/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.5000 - mse: 0.2517
# Epoch 111/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.5000 - mse: 0.2508
# Epoch 112/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.5000 - mse: 0.2554
# Epoch 113/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2552 - accuracy: 0.5000 - mse: 0.2552
# Epoch 114/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.5000 - mse: 0.2548
# Epoch 115/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.5000 - mse: 0.2498
# Epoch 116/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.5000 - mse: 0.2544
# Epoch 117/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2542 - accuracy: 0.5000 - mse: 0.2542
# Epoch 118/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.5000 - mse: 0.2497
# Epoch 119/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2537 - accuracy: 0.5000 - mse: 0.2537
# Epoch 120/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5000 - mse: 0.2486
# Epoch 121/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2532 - accuracy: 0.5000 - mse: 0.2532
# Epoch 122/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2529 - accuracy: 0.5000 - mse: 0.2529
# Epoch 123/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2527 - accuracy: 0.5000 - mse: 0.2527
# Epoch 124/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2524 - accuracy: 0.5000 - mse: 0.2524
# Epoch 125/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2473 - accuracy: 0.5000 - mse: 0.2473
# Epoch 126/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2471 - accuracy: 0.5000 - mse: 0.2471
# Epoch 127/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.5000 - mse: 0.2517
# Epoch 128/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2514 - accuracy: 0.5000 - mse: 0.2514
# Epoch 129/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2470 - accuracy: 0.5000 - mse: 0.2470
# Epoch 130/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.5000 - mse: 0.2461
# Epoch 131/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.5000 - mse: 0.2459
# Epoch 132/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.5000 - mse: 0.2456
# Epoch 133/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.5000 - mse: 0.2460
# Epoch 134/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5000 - mse: 0.2500
# Epoch 135/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2496 - accuracy: 0.5000 - mse: 0.2496
# Epoch 136/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5000 - mse: 0.2495
# Epoch 137/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.5000 - mse: 0.2451
# Epoch 138/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.5000 - mse: 0.2442
# Epoch 139/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.5000 - mse: 0.2487
# Epoch 140/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.5000 - mse: 0.2484
# Epoch 141/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2441 - accuracy: 0.5000 - mse: 0.2441
# Epoch 142/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2432 - accuracy: 0.5000 - mse: 0.2432
# Epoch 143/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2436 - accuracy: 0.5000 - mse: 0.2436
# Epoch 144/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.5000 - mse: 0.2434
# Epoch 145/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.5000 - mse: 0.2473
# Epoch 146/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2423 - accuracy: 0.5000 - mse: 0.2423
# Epoch 147/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.5000 - mse: 0.2420
# Epoch 148/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2465 - accuracy: 0.5000 - mse: 0.2465
# Epoch 149/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2422 - accuracy: 0.5000 - mse: 0.2422
# Epoch 150/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.5000 - mse: 0.2460
# Epoch 151/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2417 - accuracy: 0.5000 - mse: 0.2417
# Epoch 152/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2414 - accuracy: 0.5000 - mse: 0.2414
# Epoch 153/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2452 - accuracy: 0.5000 - mse: 0.2452
# Epoch 154/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2410 - accuracy: 0.5000 - mse: 0.2410
# Epoch 155/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2407 - accuracy: 0.5000 - mse: 0.2407
# Epoch 156/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.5000 - mse: 0.2405
# Epoch 157/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2443 - accuracy: 0.5000 - mse: 0.2443
# Epoch 158/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2441 - accuracy: 0.5000 - mse: 0.2441
# Epoch 159/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2391 - accuracy: 0.5000 - mse: 0.2391
# Epoch 160/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2395 - accuracy: 0.5000 - mse: 0.2395
# Epoch 161/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2387 - accuracy: 0.5000 - mse: 0.2387
# Epoch 162/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.5000 - mse: 0.2384
# Epoch 163/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2388 - accuracy: 0.5000 - mse: 0.2388
# Epoch 164/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2386 - accuracy: 0.5000 - mse: 0.2386
# Epoch 165/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2383 - accuracy: 0.5000 - mse: 0.2383
# Epoch 166/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2381 - accuracy: 0.5000 - mse: 0.2381
# Epoch 167/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2419 - accuracy: 0.5000 - mse: 0.2419
# Epoch 168/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2370 - accuracy: 0.5000 - mse: 0.2370
# Epoch 169/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.5000 - mse: 0.2414
# Epoch 170/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.5000 - mse: 0.2365
# Epoch 171/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2370 - accuracy: 0.5000 - mse: 0.2370
# Epoch 172/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2361 - accuracy: 0.5000 - mse: 0.2361
# Epoch 173/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2405 - accuracy: 0.5000 - mse: 0.2405
# Epoch 174/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2357 - accuracy: 0.5000 - mse: 0.2357
# Epoch 175/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.5000 - mse: 0.2354
# Epoch 176/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2352 - accuracy: 0.5000 - mse: 0.2352
# Epoch 177/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.5000 - mse: 0.2397
# Epoch 178/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2394 - accuracy: 0.5000 - mse: 0.2394
# Epoch 179/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.5000 - mse: 0.2392
# Epoch 180/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2350 - accuracy: 0.5000 - mse: 0.2350
# Epoch 181/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.5000 - mse: 0.2342
# Epoch 182/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.5000 - mse: 0.2346
# Epoch 183/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2337 - accuracy: 0.5000 - mse: 0.2337
# Epoch 184/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.5000 - mse: 0.2342
# Epoch 185/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2333 - accuracy: 0.5000 - mse: 0.2333
# Epoch 186/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.5000 - mse: 0.2338
# Epoch 187/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2375 - accuracy: 0.5000 - mse: 0.2375
# Epoch 188/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.5000 - mse: 0.2327
# Epoch 189/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.5000 - mse: 0.2325
# Epoch 190/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2322 - accuracy: 0.5000 - mse: 0.2322
# Epoch 191/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2366 - accuracy: 0.5000 - mse: 0.2366
# Epoch 192/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2364 - accuracy: 0.5000 - mse: 0.2364
# Epoch 193/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.5000 - mse: 0.2316
# Epoch 194/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.5000 - mse: 0.2321
# Epoch 195/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2318 - accuracy: 0.5000 - mse: 0.2318
# Epoch 196/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.5000 - mse: 0.2310
# Epoch 197/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2353 - accuracy: 0.5000 - mse: 0.2353
# Epoch 198/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2306 - accuracy: 0.5000 - mse: 0.2306
# Epoch 199/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.5000 - mse: 0.2310
# Epoch 200/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2308 - accuracy: 0.5000 - mse: 0.2308
# Epoch 201/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2344 - accuracy: 0.5000 - mse: 0.2344
# Epoch 202/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.5000 - mse: 0.2304
# Epoch 203/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2302 - accuracy: 0.5000 - mse: 0.2302
# Epoch 204/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.5000 - mse: 0.2293
# Epoch 205/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.5000 - mse: 0.2298
# Epoch 206/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2289 - accuracy: 0.5000 - mse: 0.2289
# Epoch 207/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2287 - accuracy: 0.5000 - mse: 0.2287
# Epoch 208/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2329 - accuracy: 0.5000 - mse: 0.2329
# Epoch 209/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.5000 - mse: 0.2328
# Epoch 210/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2281 - accuracy: 0.5000 - mse: 0.2281
# Epoch 211/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2285 - accuracy: 0.5000 - mse: 0.2285
# Epoch 212/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2321 - accuracy: 0.5000 - mse: 0.2321
# Epoch 213/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2275 - accuracy: 0.5000 - mse: 0.2275
# Epoch 214/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2272 - accuracy: 0.5000 - mse: 0.2272
# Epoch 215/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.5000 - mse: 0.2277
# Epoch 216/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2275 - accuracy: 0.5000 - mse: 0.2275
# Epoch 217/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2273 - accuracy: 0.5000 - mse: 0.2273
# Epoch 218/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2271 - accuracy: 0.5000 - mse: 0.2271
# Epoch 219/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.5000 - mse: 0.2262
# Epoch 220/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.5000 - mse: 0.2260
# Epoch 221/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2258 - accuracy: 0.5000 - mse: 0.2258
# Epoch 222/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2301 - accuracy: 0.5000 - mse: 0.2301
# Epoch 223/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.5000 - mse: 0.2254
# Epoch 224/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.5000 - mse: 0.2252
# Epoch 225/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.5000 - mse: 0.2257
# Epoch 226/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2255 - accuracy: 0.5000 - mse: 0.2255
# Epoch 227/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2253 - accuracy: 0.5000 - mse: 0.2253
# Epoch 228/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2244 - accuracy: 0.5000 - mse: 0.2244
# Epoch 229/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2287 - accuracy: 0.5000 - mse: 0.2287
# Epoch 230/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.5000 - mse: 0.2240
# Epoch 231/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2237 - accuracy: 0.5000 - mse: 0.2237
# Epoch 232/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2236 - accuracy: 0.5000 - mse: 0.2236
# Epoch 233/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2233 - accuracy: 0.5000 - mse: 0.2233
# Epoch 234/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2232 - accuracy: 0.5000 - mse: 0.2232
# Epoch 235/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2229 - accuracy: 0.5000 - mse: 0.2229
# Epoch 236/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2228 - accuracy: 0.5000 - mse: 0.2228
# Epoch 237/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.5000 - mse: 0.2232
# Epoch 238/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2268 - accuracy: 0.5000 - mse: 0.2268
# Epoch 239/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2228 - accuracy: 0.5000 - mse: 0.2228
# Epoch 240/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2226 - accuracy: 0.5000 - mse: 0.2226
# Epoch 241/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2224 - accuracy: 0.5000 - mse: 0.2224
# Epoch 242/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.5000 - mse: 0.2222
# Epoch 243/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2258 - accuracy: 0.5000 - mse: 0.2258
# Epoch 244/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2211 - accuracy: 0.5000 - mse: 0.2211
# Epoch 245/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2216 - accuracy: 0.5000 - mse: 0.2216
# Epoch 246/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2251 - accuracy: 0.5000 - mse: 0.2251
# Epoch 247/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2212 - accuracy: 0.5000 - mse: 0.2212
# Epoch 248/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2210 - accuracy: 0.5000 - mse: 0.2210
# Epoch 249/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.5000 - mse: 0.2208
# Epoch 250/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.5000 - mse: 0.2200
# Epoch 251/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.5000 - mse: 0.2198
# Epoch 252/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2203 - accuracy: 0.5000 - mse: 0.2203
# Epoch 253/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2200 - accuracy: 0.5000 - mse: 0.2200
# Epoch 254/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2236 - accuracy: 0.5000 - mse: 0.2236
# Epoch 255/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2196 - accuracy: 0.5000 - mse: 0.2196
# Epoch 256/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2194 - accuracy: 0.5000 - mse: 0.2194
# Epoch 257/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2186 - accuracy: 0.5000 - mse: 0.2186
# Epoch 258/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2227 - accuracy: 0.5000 - mse: 0.2227
# Epoch 259/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.5000 - mse: 0.2225
# Epoch 260/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2179 - accuracy: 0.5000 - mse: 0.2179
# Epoch 261/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2222 - accuracy: 0.5000 - mse: 0.2222
# Epoch 262/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.
500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1757 - accuracy: 0.7500 - mse: 0.1757
# Epoch 490/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1764 - accuracy: 0.7500 - mse: 0.1764
# Epoch 491/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1761 - accuracy: 0.7500 - mse: 0.1761
# Epoch 492/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1760 - accuracy: 0.7500 - mse: 0.1760
# Epoch 493/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 0.7500 - mse: 0.1752
# Epoch 494/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.7500 - mse: 0.1757
# Epoch 495/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1755 - accuracy: 0.7500 - mse: 0.1755
# Epoch 496/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1753 - accuracy: 0.7500 - mse: 0.1753
# Epoch 497/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1745 - accuracy: 0.7500 - mse: 0.1745
# Epoch 498/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1742 - accuracy: 0.7500 - mse: 0.1742
# Epoch 499/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.7500 - mse: 0.1741
# Epoch 500/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1747 - accuracy: 0.7500 - mse: 0.1747

# %% [markdown]
# There are a few tools we can use to look at the network as well.  ```summary``` will give an overview of the network, including how many parameters are used.  The ```None``` in the Output Shape column corresponds to the number of input values fed through the network.  ```summary``` must be called *after* ```fit```.

# %%
network1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (2, 10)                   30
# _________________________________________________________________
# dense_1 (Dense)              (2, 1)                    11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# If we want to look at the actual weights used by the network, we can use the ```_layers``` attribute of the network:

# %%
network1._layers
# Out:
# [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7fef0ef746a0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fef493dad30>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fef493da978>]

# %% [markdown]
# Each of the elements in this list represents the things associated with one of the layers of the network.  The ```InputLayer``` doesn't actually interest us (it deals with reading in data), but we can look at the weights of the hidden layer:

# %%
print(network1._layers[1].weights)
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(2, 10) dtype=float32, numpy=
# array([[ 0.5739094 ,  0.22329704,  0.4760294 ,  0.46088374, -0.6657106 ,
#         -0.69073796,  0.6689513 , -0.01434495,  0.6355625 , -0.5258052 ],
#        [ 0.18132979, -0.22303371,  0.5925296 ,  0.47579268,  0.34371257,
#         -0.6404746 , -0.6673853 ,  0.4837899 ,  0.27337003,  0.63649404]],
#       dtype=float32)>, <tf.Variable 'dense/bias:0' shape=(10,) dtype=float32, numpy=
# array([ 8.1165962e-02, -4.7130053e-04,  4.7084448e-04,  5.8029778e-04,
#         2.4534960e-04,  0.0000000e+00, -3.1258233e-04,  9.4481282e-02,
#         3.0566904e-01, -3.6446322e-04], dtype=float32)>]

# %% [markdown]
# and the output layer:

# %%
print(network1._layers[2].weights)
# Out:
# [<tf.Variable 'dense_1/kernel:0' shape=(10, 1) dtype=float32, numpy=
# array([[ 0.20609766],
#        [-0.38113987],
#        [-0.41323787],
#        [-0.48476037],
#        [-0.24116097],
#        [ 0.26544935],
#        [-0.85316044],
#        [ 0.25013894],
#        [ 0.8048678 ],
#        [-0.3547065 ]], dtype=float32)>, <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([0.3970174], dtype=float32)>]

# %% [markdown]
# You can see the weights here, but there is a lot of extraneous information because the weights are TensorFlow variables.
# To convert them to Numpy variables we can use the `numpy()` command:

# %%
print(network1._layers[1].weights[0].numpy().T)
print()
print(network1._layers[1].weights[1].numpy())
# Out:
# [[ 0.5739094   0.18132979]
#  [ 0.22329704 -0.22303371]
#  [ 0.4760294   0.5925296 ]
#  [ 0.46088374  0.47579268]
#  [-0.6657106   0.34371257]
#  [-0.69073796 -0.6404746 ]
#  [ 0.6689513  -0.6673853 ]
#  [-0.01434495  0.4837899 ]
#  [ 0.6355625   0.27337003]
#  [-0.5258052   0.63649404]]
#
# [ 8.1165962e-02 -4.7130053e-04  4.7084448e-04  5.8029778e-04
#   2.4534960e-04  0.0000000e+00 -3.1258233e-04  9.4481282e-02
#   3.0566904e-01 -3.6446322e-04]

# %% [markdown]
# We can also use the network for prediction:

# %%
print(network1.predict(X_xor))
# Out:
# [[0.5933616 ]
#  [0.55942214]
#  [0.2150839 ]
#  [0.58839035]]

# %% [markdown]
# Remember that the network is trying to approximate the values [1, 0, 0, 1].  Let's look at the history of the loss and accuracy over the epochs of training the network using the ```history``` of the trained network:

# %%
plt.plot(history1.history['accuracy'], label='Accuracy')
plt.plot(history1.history['mse'], label='MSE')
plt.ylim([0, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# Let's also look at the decision surface of this network:

# %%
plot_XOR_network(network1)

# %% [markdown]
# We can also add more layers and have more nodes in each layer:

# %%
network2 = keras.Sequential()
network2.add(keras.layers.Dense(50, activation='relu'))
network2.add(keras.layers.Dense(25, activation='relu'))
network2.add(keras.layers.Dense(12, activation='relu'))
network2.add(keras.layers.Dense(1))

loss_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.SGD(learning_rate=0.005)
network2.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

history2 = network2.fit(X_xor, y_xor, batch_size=2, epochs=500, verbose=0)

# %%
network2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (2, 50)                   150
# _________________________________________________________________
# dense_3 (Dense)              (2, 25)                   1275
# _________________________________________________________________
# dense_4 (Dense)              (2, 12)                   312
# _________________________________________________________________
# dense_5 (Dense)              (2, 1)                    13
# =================================================================
# Total params: 1,750
# Trainable params: 1,750
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This model has far more complexity than is necessary for this problem - a total of 1,750 parameters is orders of magnitude larger than necessary, but it still finds a good solution.

# %%
plt.plot(history2.history['accuracy'], label='Accuracy')
plt.plot(history2.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %%
plot_XOR_network(network2)

# %% [markdown]
# ## Loss Functions and Softmax

# %% [markdown]
# Using The Euclidean distance of the outputs from the true values probably isn't the best loss function to be using: it is designed for regression problems. Instead, we can use the cross entropy loss.  To do this, one thing we need to do is change our expected outputs from being 0 or 1 to be "one-hot-encoded:"

# %%
y_xor_one_hot = keras.utils.to_categorical(y_xor, 2)
print(y_xor_one_hot)
# Out:
# [[0. 1.]
#  [1. 0.]
#  [1. 0.]
#  [0. 1.]]

# %% [markdown]
# In one-hot-encoding, each output is now a vector with zero at each class label that is not correct for the associated input and one at the class label that is correct.  One thing to note with this modification is that our network will now have two outputs.
#
# It's also useful to restrict the outputs of our network to look like probabilities.  One way to do this would be to normalize the outputs to be
# \begin{align*}
# z_1' &= \frac{z_1}{z_1 + z_2} \\
# z_2' &= \frac{z_2}{z_1 + z_2}
# \end{align*}
# which gives us $z_1'$ and $z_2'$ values each between zero and one and summing to one.  One thing to keep in mind here is that although these now form a probability distribution, it isn't necessarily accurate to view $z_1'$ as the "probability that the input is of class one" because the approximation given by our network may not be a perfect statstical model of that fact.
#
# Another way to do this would be to take the hard max of the outputs,
# \begin{align*}
# z_1' &= \begin{cases} 1 & z_1 \geq z_2 \\ 0 & z_1 < z_2 \end{cases} \\
# z_2' &= \begin{cases} 0 & z_1 \geq z_2 \\ 1 & z_1 < z_2 \end{cases},
# \end{align*}
# which has similar nice properties but is unfortunately not differentiable, so we can't actually use it for classification.
#
# A comprimise between these two is softmax.  For our two raw outputs, $z_1$ and $z_2$, the softmax activation function is calculated as
# \begin{align*}
# \text{softmax}(z_1) &= \frac{e^{z_1}}{e^{z_1} + e^{z_2}} \\
# \text{softmax}(z_2) &= \frac{e^{z_2}}{e^{z_1} + e^{z_2}}
# \end{align*}
# This is very similar to normalization, but with the exponential function of the raw inputs instead.  This means that values will be driven to behave more similarly to the hardmax while still being differentiable.
#
# In the network below we use the ```BinaryCrossentropy``` loss function  which is cross entropy for two classes with a softmax activation on our output layer.

# %%
network3 = keras.Sequential()
network3.add(keras.layers.Dense(10, activation='relu'))
network3.add(keras.layers.Dense(2, activation='softmax'))

loss_fn = keras.losses.BinaryCrossentropy()
opt = keras.optimizers.SGD(learning_rate=0.01)
network3.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history3 = network3.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=600, verbose=0)

# %%
plt.plot(history3.history['accuracy'], label='Accuracy')
plt.plot(history3.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# To visualize the decision surface, we will plot $z_1 - z_2$.  This is a trick we will use throughout the rest of the notebook.

# %%
plot_XOR_network(network3, two_outputs=True)

# %% [markdown]
# ## Nonconvex Optimization

# %% [markdown]
# For linear models, finding a solution that minimizes some quantity of interest was relatively easy because the error surface has a single global minimum.  Whenever the error function satisfies a certain condition known as "convexity", this is guaranteed to be the case.
# Here's an example of a loss surface of a convex problem:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2)
points = np.r_[True, y[1:] <= y[:-1]] & np.r_[y[:-1] <= y[1:], True]
plt.plot(x, y, label='Loss Surface')
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.title("Convex Optimization")
plt.xticks([])
plt.yticks([])
plt.scatter(x[points], y[points], c='r', label='minimum')
plt.legend();

# %% [markdown]
# As we change the weights of the model, we move around on the blue curve.  The goal is to find a configuration of weights that places us at the location of the red dot, which is the minimum of this function.

# %% [markdown]
# However, due to the nonlinearity of neural networks, there may be more than one minimum.  For example:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2) + 5*np.sin(np.pi*x)
points = np.r_[True, y[1:] < y[:-1]] & np.r_[y[:-1] < y[1:], True]
plt.plot(x, y, label="Loss Surface")
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.xticks([])
plt.yticks([])
plt.title("Nonconvex Optimization")
plt.scatter(x[points], y[points], c='r', label='minima')
plt.legend();

# %% [markdown]
# In this case, there is a single global minimum that represents the optimal solution, but there are a number of other *local* minima.
#
# Gradient descent and many of its variants are the most commonly used algorithms for optimizing the weights of neural networks.  Gradient descent can be thought of as behaving like a ball that is placed on the the loss surface - it rolls down hills.  That means that if an initial configuration of a neural network lies somewhere in a valley around one of the local minima, gradient descent will push it towards that local minimum rather than the global minimum.
# However, that may or may not be a problem!  We are interested in solutions that have high prediction accuracy - not necessarily finding the global minimum.

# %% [markdown]
# ## Gradient Descent Modifications and Regularization

# %% [markdown]
# The simple SGD algorithm has a modification that can help with shallow local minima and plateaus in the loss surface - momentum.  Intuitively, this is the same as the idea would be in physics, where the model builds momentum as it travels, and can continue to follow that momentum rather than just going in the direction of most change.  This helps avoid shallow local minima and can prevent the model from slowing down too much on plateaus.

# %%
opt = keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)

# %% [markdown]
# We can also add weight decay to our model, where weights are driven towards small values to reduce the likelihood of overfitting and smooth the loss surface:

# %%
reg = keras.regularizers.l2(1e-4)
network4 = keras.Sequential()
network4.add(keras.layers.Dense(10, activation='relu', kernel_regularizer=reg, bias_regularizer=reg))
network4.add(keras.layers.Dense(2, activation='softmax', kernel_regularizer=reg, bias_regularizer=reg))

# %% [markdown]
# The rest of our setup is the same as it has been previously.

# %%
loss_fn = keras.losses.BinaryCrossentropy()

network4.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history4 = network4.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=100, verbose=0)

# %%
plt.plot(history4.history['accuracy'], label='Accuracy')
plt.plot(history4.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# This network trains *much* faster than the previous models.  While testing this notebook, the model frequently achieved zero loss by epoch 50.

# %%
plot_XOR_network(network4, two_outputs=True)

# %% [markdown]
# There are also more complex optimizers, such as the [Adam optimizer](https://arxiv.org/pdf/1412.6980.pdf) designed by Diederik Kingma and Jimmy Ba.  It uses a variety of techniques like adaptive learning rates and momentums to provide competitive performance.  To use it in Keras, call it as

# %%
opt = keras.optimizers.Adam()

# %% [markdown]
# It has default parameters that empirically work well on a wide class of problems.

# %% [markdown]
# ## Complex Problems

# %% [markdown]
# [Neural Networks, Manifolds, and Topology](https://colah.github.io/posts/2014-03-NN-Manifolds-Topology/) by Christopher Olah has animated versions for $\tanh$ networks of some of the investigations and examples shown here.

# %% [markdown]
# Now let's consider a slightly more difficult problem for neural networks:

# %%
r1 = 0.5
r2 = np.sqrt(2*r1**2)
r3 = np.sqrt(r1**2 + r2**2)

fig = plt.figure()
ax = fig.add_subplot(111)

circle = plt.Circle((0, 0), r1)
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, color='r')
ax.add_artist(circle)
ax.add_artist(annulus)
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# By itself this is a relatively easy problem - if we convert to polar coordinates, we can just threshold based on the radius and have a very simple classifier that achieves 100% accuracy.  However, if we use the raw $x_1$ and $x_2$ inputs to a neural network, that information must be learned by the network.  The network must be able to construct a closed region in the plane, which requires more complexity than was necessary for XOR.
#
# For training a network we need specific inputs, so we will get 500 points from the circle and 500 from the annulus with their associated class labels:

# %%
X_circle = []
y_circle = []
for i in range(500):
    # Circle
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) > r1:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(0)
        
    # Annulus
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) < r2 or np.linalg.norm(vec) > r3:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(1)
    
X_circle = np.array(X_circle)
X_circle = X_circle.astype('float32')
y_circle = np.array(y_circle)
y_circle_one_hot = keras.utils.to_categorical(y_circle, 2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X_circle[y_circle==0, 0], X_circle[y_circle==0, 1])
ax.scatter(X_circle[y_circle==1, 0], X_circle[y_circle==1, 1], c='r')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# Let's train a simple network on this and keep trying until we make sure we get a better solution than random:

# %%
while True:
    network5 = keras.Sequential()
    network5.add(keras.layers.Dense(2, activation='relu'))
    network5.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network5.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    
    history5 = network5.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    print('Trained one network to {} accuracy'.format(history5.history['accuracy'][-1]))
    if history5.history['accuracy'][-1] > 0.78:
        break
# Out:
# Trained one network to 0.6579999923706055 accuracy
# Trained one network to 0.800000011920929 accuracy

# %%
plt.plot(history5.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network5, two_outputs=True)

# %% [markdown]
# This network gets about 80% accuracy, which is somewhat close to the best that can be expected from this architecture.  Let's look at what it actually does to the data.  The first thing it does is apply the weights of the first layer to transform the data:

# %%
weights = network5._layers[1].weights[0].numpy().T
biases = network5._layers[1].weights[1].numpy()

X_transform = np.matmul(weights, X_circle.T).T + biases
plt.scatter(X_transform[y_circle==0, 0], X_transform[y_circle==0, 1])
plt.scatter(X_transform[y_circle==1, 0], X_transform[y_circle==1, 1], c='r')

plt.axhline(0, c='k', alpha=0.25)
plt.axvline(0, c='k', alpha=0.25)

plt.xlabel('Pre-ReLU output of node one')
plt.ylabel('Pre-ReLU output of node two');

# %% [markdown]
# Here, each axis is the output of the two hidden nodes before taking the ReLU.  When mapping the data onto these "axes" the network has shifted the data down and to the left while stretching it out diagonally.
#
# The next step is to apply the ReLU - we'll apply it to node one first, which is the horizontal axis (plotting with alpha since points will now be more overlayed):

# %%
X_transform[:, 0] = np.maximum(X_transform[:, 0], 0)
plt.axhline(0, c='k', alpha=0.25)
plt.axvline(0, c='k', alpha=0.25)
plt.scatter(X_transform[y_circle==0, 0], X_transform[y_circle==0, 1], alpha=0.1)
plt.scatter(X_transform[y_circle==1, 0], X_transform[y_circle==1, 1], c='r', alpha=0.1)
plt.xlabel('Post-ReLU output of node one')
plt.ylabel('Post-ReLU output of node two');

# %% [markdown]
# Every data point with a horizontal coordinate below zero has its horizontal coordinate taken to zero - effectively shoving all the negative data to zero on that axis.
#
# We can do the same thing with the second node, which is the vertical axis:

# %%
X_transform = np.maximum(X_transform, 0)
plt.axhline(0, c='k', alpha=0.25)
plt.axvline(0, c='k', alpha=0.25)
plt.scatter(X_transform[y_circle==0, 0], X_transform[y_circle==0, 1], alpha=0.1)
plt.scatter(X_transform[y_circle==1, 0], X_transform[y_circle==1, 1], c='r', alpha=0.1)
plt.xlabel('Post-ReLU output of node one')
plt.ylabel('Post-ReLU output of node two');

# %% [markdown]
# This doesn't look particularly useful, but notice that all of the blue data points are in the lower left corner.  That means that when the decision boundary is drawn on, they can (mostly) be on one side, even if there is significant mixing with the red points.
#
# That decision boundary comes from the hidden to output weights, as that is the linear classifier the network is using.  In the new space created by applying the first layer, the decision boundary is a straight line:

# %%
weights = network5._layers[2].weights[0].numpy().T[0, :] - network5._layers[2].weights[0].numpy().T[1, :]
biases = network5._layers[2].weights[1].numpy()[0] - network5._layers[2].weights[1].numpy()[1]

fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax.scatter(X_transform[y_circle==0, 0], X_transform[y_circle==0, 1], c='b', alpha=0.1)
ax.scatter(X_transform[y_circle==1, 0], X_transform[y_circle==1, 1], c='r', alpha=0.1)

ax.axhline(0, c='k', alpha=0.25)
ax.axvline(0, c='k', alpha=0.25)

x_vals = np.array(ax.get_xlim())
y_lims = np.array(ax.get_ylim())
y_vals = -weights[0]/weights[0]*x_vals - biases/weights[1]
ax.plot(x_vals, y_vals, 'k');

ax.set_xlim(x_vals)
ax.set_ylim(y_lims)
ax.set_xlabel('Post-ReLU output of node one')
ax.set_ylabel('Post-ReLU output of node two')

delta = 0.01
xmin=-1.1;xmax=1.1;ymin=-1.1;ymax=1.1
xs = np.arange(xmin, xmax, delta)
ys = np.arange(ymin, ymax, delta)
x_grid, y_grid = np.meshgrid(xs, ys)

xs = x_grid.reshape(-1)
ys = y_grid.reshape(-1)
x = np.vstack((xs, ys))
Z = network5.predict(x.T)
Z = Z[:, 1] - Z[:, 0]
Z = Z.reshape(x_grid.shape)

im = ax2.imshow(Z, origin='lower',
            cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-0.001, vmax=0.001)

ax2.set_xlabel('$x_1$')
ax2.set_ylabel('$x_2$')

circle = plt.Circle((0, 0), r1, alpha=0.5, edgecolor='k')
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, facecolor='r', alpha=0.5, edgecolor='k')
ax2.add_artist(circle)
ax2.add_artist(annulus);

# %% [markdown]
# In the left plot, we have the decision boundary displayed in the embedding space resulting from the transformations of the inner nodes.  On the right, we have the decision boundary displayed in the original space.

# %% [markdown]
# Now let's train a network that solves this, with three nodes in its hidden layer.  We may have to train it multiple times for it to find a solution with 100% accuracy.

# %%
while True:
    network6 = keras.Sequential()
    network6.add(keras.layers.Dense(3, activation='relu'))
    network6.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network6.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    history6 = network6.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    
    print('Trained one network to {} accuracy'.format(history6.history['accuracy'][-1]))
    if history6.history['accuracy'][-1] >= 0.99:
        break
# Out:
# Trained one network to 0.9940000176429749 accuracy

# %%
plt.plot(history6.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network6, two_outputs=True)

# %% [markdown]
# This should have perfect or near perfect accuracy on the data we are considering - if it is perfect, it likely has a hexagonal shape, and if it is imperfect it has like found a square shape with the corners overlapping the annulus.

# %% [markdown]
# ### Exercise
#
# What do you expect the decision boundaries of solutions using a sigmoid (```sigmoid``` or ```tanh``` as the activation function) to look like?  Try doing it, and see how well it matches your expectations.

# %% [markdown]
# Now, let's look at what the network is doing to the data - the weights and biases in the first layer are

# %%
weights = network6._layers[1].weights[0].numpy().T
biases = network6._layers[1].weights[1].numpy()
print(weights)
print()
print(biases)
# Out:
# [[-3.6281955  -0.46003148]
#  [ 2.1911983  -2.6626785 ]
#  [ 1.0165716   2.7855551 ]]
#
# [-0.55349636 -0.4610786  -0.6552199 ]

# %% [markdown]
# Those serve to project the data into three dimensions.

# %%
X_transform = np.matmul(weights, X_circle.T).T + biases
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_transform[y_circle==0, 0], X_transform[y_circle==0, 1], X_transform[y_circle==0, 2])
ax.scatter(X_transform[y_circle==1, 0], X_transform[y_circle==1, 1], X_transform[y_circle==1, 2], c='r');
ax.set_xlabel('Node one pre-ReLU')
ax.set_ylabel('Node two pre-ReLU')
ax.set_zlabel('Node three pre-ReLU');

# %% [markdown]
# Having three dimensions over the two in the previous example may not seem like it helps, but if we apply ReLU we get the following embedding:

# %%
X_transform = np.maximum(X_transform, 0)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_transform[y_circle==0, 0], X_transform[y_circle==0, 1], X_transform[y_circle==0, 2])
ax.scatter(X_transform[y_circle==1, 0], X_transform[y_circle==1, 1], X_transform[y_circle==1, 2], c='r')
ax.set_xlabel('Node one post-ReLU')
ax.set_ylabel('Node two post-ReLU')
ax.set_zlabel('Node three post-ReLU');

# %% [markdown]
# Those three dimensions mean that when the nonlinear ReLU is applied, and the data is squished to zero on its negative axes, the blue points in the circle are pulled away from the red dots in the annulus, and we can draw the plane (rather than the line in two dimensions) that separates the data well.

# %% [markdown]
# Another way of looking at this network is that each ReLU node can be either on or off - so regions can be described as a bit string consisting of which nodes are activated versus deactivated.  The following image shows the lines along which each node switches, with the center consisting of the region where all three are deactivated.  Lines are color coordinated with the nodes in the below architecture diagram.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

weights = network6._layers[1].weights[0].numpy().T
biases = network6._layers[1].weights[1].numpy()
colors = ['magenta', 'cyan', 'orange']
for i in range(weights.shape[0]):
    x_vals = np.array([-1, 1])
    y_vals = -weights[i, 0]/weights[i, 1]*x_vals - biases[i]/weights[i, 1]
    ax.plot(x_vals, y_vals, c= colors[i])
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
circle = plt.Circle((0, 0), r1)
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, color='r')
ax.add_artist(circle)
ax.add_artist(annulus)
ax.set_aspect('equal', 'box')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$');

# %% [markdown]
# <img style="padding:10px;width:50%;" alt="Colored network achitecture" src="https://github.com/asabenhur/CS345/raw/master/notebooks/figures/colored_nodes.png">

# %% [markdown]
# Note that there are only seven regions, as opposed to the potential eight from bit patterns of length three - there isn't an input we can give to the network that will result in all the ReLU nodes being activated.
#
# If we look at the decision boundary along with the lines showing the ReLU breaks, we get an image that looks like this:

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
delta = 0.01
xmin=-1.1;xmax=1.1;ymin=-1.1;ymax=1.1
xs = np.arange(xmin, xmax, delta)
ys = np.arange(ymin, ymax, delta)
x_grid, y_grid = np.meshgrid(xs, ys)

xs = x_grid.reshape(-1)
ys = y_grid.reshape(-1)
x = np.vstack((xs, ys))
Z = network6.predict(x.T)
Z = np.log(Z[:, 1]) - np.log(Z[:, 0])
Z = Z.reshape(x_grid.shape)

im = ax.contour(x_grid, y_grid, Z, 0)

weights = network6._layers[1].weights[0].numpy().T
biases = network6._layers[1].weights[1].numpy()
colors = ['magenta', 'cyan', 'orange']
for i in range(weights.shape[0]):
    x_vals = np.array([-1, 1])
    y_vals = -weights[i, 0]/weights[i, 1]*x_vals - biases[i]/weights[i, 1]
    ax.plot(x_vals, y_vals, c= colors[i])
    
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])

circle = plt.Circle((0, 0), r1)
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, color='r')
ax.add_artist(circle)
ax.add_artist(annulus)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$');

ax.set_aspect('equal', 'box');

# %% [markdown]
# The decision surface is linear within each region corresponding to a bit pattern, but changes angle whenever it reaches one of the ReLU shifts.  ReLU neural networks actually form piecewise linear structures - within each of these linear regions arising from the ReLU activations, a single linear classifier is used.  As the ReLU boundaries are crossed, that linear classifier switches but connects along at the boundary.  One additional note to make is that the region where all ReLU nodes are not active is constant, so the linear classifier in that region is not able to do anything beyond return a single value.

# %% [markdown]
# ### Exercise
#
# Based on this linear region structure, why can a network with two nodes in a single hidden layer not solve the circle versus annulus problem?

# %% [markdown]
# ### Large Network

# %% [markdown]
# We can also train a wider and deeper network on this problem to get a good solution nearly everytime.

# %%
network7 = keras.Sequential()
network7.add(keras.layers.Dense(8, activation='relu'))
network7.add(keras.layers.Dense(8, activation='relu'))
network7.add(keras.layers.Dense(8, activation='relu'))
network7.add(keras.layers.Dense(2, activation='softmax'))

loss_fn = keras.losses.BinaryCrossentropy()
opt = keras.optimizers.Adam()
network7.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
history7 = network7.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=200, verbose=0)

# %%
plt.plot(history7.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network7, two_outputs=True)

# %% [markdown]
# ## Comments
#
# 1. Some of the intuition from these small, two-input networks may not carry over in expected ways to higher dimensional problems.  Unfortunately, building intuition for those more complex problems is typically difficult due to the limited ability to analyze high dimensional networks.  We will discuss more complex problems in our next notebook.
# 2. Until relatively recently, one of the best methods for hyperparameter selection with neural networks was random search.  More sophisticated methods exist now, but without insight into the dataset it can be difficult to determine how to structure network architecture and training process
# 3. Keras used to be independent from the chosen backend, but its creator now works for Google (the makers of TensorFlow), and backends like PyTorch are no longer being updated, so the "recommended" backend is TensorFlow.  Keras is also being more closely tied into TensorFlow.
